# %%
import subprocess, os, sys, signal, pip, collections, optparse, sys, tempfile, re, optparse
import rpy2
from joblib import Parallel, delayed
import multiprocessing
import threading
import time
import numpy as np

# %%
# Setting the output folder where all the results would be stored
outputFolder = '/mnt/mr01-home01/mqbsxsm2/scratch/Scott_Wilcockson_SC/output/'

# %%
def expanderuser(path):
    """Replaces the ~ with the users home directory"""
    if path.startswith("~"):
        return os.path.expanduser("~") + path[1: ]
    return path

def multiple_match(regex, old_name, name):
    report_error(regex+" matched both " + old_name + " and " + name + "strickter regex required")

def do_walk(source, regex, target_path, onerror=None, followlinks=False, verbose=True, divider=None, sort=None):
    """
    Walker method
    Inputs are:
    source Parent directory to be walked through
    onerror is a function on underlying os.listdir fails
    followlinks would allow following symbolic links
        WARNING Be aware that setting followlinks to True can lead to infinite
           recursion if a link points to a parent directory of itself.
           walk() does not keep track of the directories it visited already.
    verbose: Flag passed to action methods to provide more output
    """
    source = expanderuser(source)
    (names_number, names_path) = tempfile.mkstemp()
    re_object = re.compile(regex)
    file_paths = []
    with open(names_path, 'w') as f:
        # Must be topdown=True otherwise walk will process subdirectories before checking them
        for root, dirs, files in os.walk(source, topdown=True, onerror=onerror, followlinks=followlinks):
            for name in files:
                if re_object.search(name):
                    file_path = os.path.join(root, name)
                    f.write(file_path)
                    f.write("\n")
                    file_paths.append(file_path)
                    if verbose:
                        print("Merging",file_path)
                #else:
                #    print "NO",name, root
    if len(file_paths) == 0:
        report_error("NO files found to match "+ regex)
    if divider:
        if sort:
            merge_files(file_paths, names_path, target_path, verbose=verbose, divider = divider, sort = sort)
        else:
            merge_files(file_paths, names_path, target_path, verbose=verbose, divider = divider)
    else:
        if sort:
            merge_files(file_paths, names_path, target_path, verbose, sort=sort)
        else:
            merge_files(file_paths, names_path, target_path, verbose)

# %%
def report_error(error):
    """Prints the error, and exits -1"""
    print(error) 
    sys.stderr.write(error)
    sys.stderr.write("\n")
    sys.stderr.flush()
    sys.exit(1)


def remove_common(names):
    start = names[0]
    end = names[0]
    for name in names:
        while len(start) > 0 and not(name.startswith(start)):
            start = start[: -1]
        while len(end) > 0 and not(name.endswith(end)):
            end = end[1:]
    new_names = []
    for name in names:
        new_name = name[len(start): -len(end)]
        new_names.append("C"+new_name)
    return new_names


def remove_symbols(s):
    if s.find("__") == -1:
        return s
    # Patterns used by Galaxy
    s = s.replace("__cb__", ']')
    s = s.replace("__cc__", '}')
    s = s.replace("__dq__", '"')
    s = s.replace("__lt__", '<')
    s = s.replace("__gt__", '>')
    s = s.replace("__ob__", '[')
    s = s.replace("__oc__", '{')
    s = s.replace("__sq__", "'")
    # Patterns added by Christian
    s = s.replace("__in__", '%in%')
    s = s.replace("__not__", '!')
    end = -2
    # tab = 9
    # | = 124
    while True:
        start = s.find("__", end + 2) + 2
        if start == 1:
            return s
        end = s.find("__", start)
        if end == -1:
            return s
        part = s[start: end]
        try:
            ascii = int(part)
            s = s.replace("__" + part + "__", chr(ascii))
            end = -2
        except ValueError:
            pass
    return s


def clean_part(part):
    part = part.strip()
    part = part.replace("\t", "__9__")
    return part


def return_blank():
    return "0"


def black_dict():
    return collections.defaultdict(return_blank)


def merge_files(file_paths, names_path, target_path, verbose=False, divider="\t", sort = None):
    if sort:
        if sort == "column_names":
            column_sort = True
            row_sort = False
        elif sort == "row_names":
            column_sort = False
            row_sort = true
        elif sort == "both":
            column_sort = True
            row_sort = True
        elif sort == "none":
            column_sort = False
            row_sort = False
        else:
            report_error("Unexpected value: " + sort + " for sort parameter. Legeal values are: column_names, row_names, both or none")
    else:
        column_sort = False
        row_sort = False

    names = []
    with open(names_path, 'r') as f:
        for line in f:
            line = line.strip()
            if len(line) > 0:
                names.append(line)
    if len(names) != len(file_paths):
        report_error("Found " + str(len(file_paths)) + " file_paths but " + names_path + " contains " + str(len(names)) + " lines.")
    new_names = remove_common(names)
    clean_divider = remove_symbols(divider)
    all_values = collections.defaultdict(black_dict)
    for count, file_path in enumerate(file_paths):
        mis_match = 0
        with open(file_path, 'r') as f:
            for line in f:
                parts = line.strip().split(clean_divider)
                if len(parts) == 2:
                    key = clean_part(parts[0])
                    value = clean_part(parts[1])
                    all_values[key][new_names[count]] = value
                else:
                    mis_match+= 1
                    if verbose:
                        if mis_match < 5:
                            print("ignoring following line from", file_path)
                            print(line)
        if mis_match > 0:
            print("In file " + file_path + " " + str(mis_match) + " lines did not have 1 divider (" + clean_divider + ") " + divider)

    if column_sort:
        new_names = sorted(new_names)
    if row_sort:
        row_names = sorted(all_values.keys())
    else:
        row_names = all_values.keys()

    with open(target_path, 'w') as f:
        for name in new_names:
            f.write("\t")
            f.write(name)
        f.write("\n")
        for key in row_names:
            f.write(key)
            for name in new_names:
                f.write("\t")
                f.write(all_values[key][name])
            f.write("\n")

# %%
HTSEQFolder = outputFolder + 'htseq_output/'
HTSEqFile = outputFolder + 'AllHtseqCounts_rep2.tsv'
do_walk(HTSEQFolder, '_R1_001.txt', HTSEqFile, onerror=None, followlinks=False, verbose=True, divider=None, sort="both")
# Out:
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B93_S128_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B21_S100_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B10_S162_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B35_S158_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B27_S117_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B25_S101_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B66_S187_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B60_S186_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B88_S191_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B77_S181_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B22_S164_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B37_S103_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B05_S153_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B39_S119_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B54_S185_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B19_S116_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B04_S161_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B53_S177_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B92_S136_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B91_S144_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B06_S145_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B68_S132_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B55_S122_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B84_S174_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B28_S149_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B46_S152_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B61_S123_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B74_S133_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B73_S141_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B49_S121_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B18_S147_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B13_S115_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B82_S190_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B16_S163_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B48_S168_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B01_S113_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B80_S134_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B72_S188_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B58_S170_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B33_S118_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B56_S130_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B24_S148_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B59_S178_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B32_S110_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B64_S171_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B40_S151_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B63_S139_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B02_S105_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B42_S167_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B07_S114_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B38_S111_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B76_S189_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B26_S109_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B17_S155_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B14_S107_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B75_S125_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B96_S176_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B11_S154_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B95_S184_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B86_S135_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B57_S138_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B44_S112_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B29_S157_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B03_S97_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B85_S143_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B94_S192_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B34_S150_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B20_S108_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B52_S169_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B43_S104_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B65_S179_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B62_S131_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B41_S159_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B78_S173_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B30_S165_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B15_S99_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B51_S137_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B70_S172_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B36_S166_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B31_S102_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B50_S129_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B81_S126_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B90_S175_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B67_S124_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B45_S120_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B12_S146_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B69_S140_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B89_S183_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B47_S160_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B08_S106_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B79_S142_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B71_S180_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B83_S182_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B09_S98_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B87_S127_R1_001.txt
# Merging /mnt/mr01-home01/mqbsxsm2/scratch/Amy_Adlard_Single_cell_Second_Dataset/output/htseq_output/B23_S156_R1_001.txt
